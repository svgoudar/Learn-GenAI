# %% [markdown]
# ::::{grid} 1 1 2 3
# :gutter: 3
#
# :::{grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Foundations</span>
# ^^^
#
# * [What is Generative AI?](generative_ai/foundations/What_is_GenAI)
# * [Generative vs. Discriminative Models](generative_ai/foundations/Generative_vs_Discriminative)
# * [Probability & Statistics Basics](generative_ai/foundations/Probability_and_Statistics)
# * [Neural Networks Fundamentals](generative_ai/foundations/Neural_Networks)
#
# :::
#
# :::{grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Core Architectures</span>
# ^^^
#
# * [Autoencoders (AEs)](generative_ai/architectures/Autoencoders)
# * [Variational Autoencoders (VAEs)](generative_ai/architectures/VAEs)
# * [Generative Adversarial Networks (GANs)](generative_ai/architectures/GANs)
# * [Diffusion Models](generative_ai/architectures/Diffusion_Models)
# * [Transformers & LLMs](generative_ai/architectures/Transformers)
# * [Energy-Based Models](generative_ai/architectures/Energy_Based_Models)
#
# :::
#
# :::{grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Large Language Models</span>
# ^^^
#
# * [LLM Architecture](generative_ai/llms/Architecture)
# * [Tokenization](generative_ai/llms/Tokenization)
# * [Attention Mechanisms](generative_ai/llms/Attention)
# * [Pre-training & Fine-tuning](generative_ai/llms/Training)
# * [Prompt Engineering](generative_ai/llms/Prompt_Engineering)
# * [RAG & Retrieval](generative_ai/llms/RAG)
#
# :::
#
# :::{grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Image Generation</span>
# ^^^
#
# * [Stable Diffusion](generative_ai/image/Stable_Diffusion)
# * [DALL-E & Imagen](generative_ai/image/DALLE_Imagen)
# * [GANs for Images](generative_ai/image/Image_GANs)
# * [Image Conditioning](generative_ai/image/Conditioning)
# * [ControlNet & Adapters](generative_ai/image/ControlNet)
#
# :::
#
# :::{grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Multimodal AI</span>
# ^^^
#
# * [Vision-Language Models](generative_ai/multimodal/Vision_Language)
# * [Text-to-Image](generative_ai/multimodal/Text_to_Image)
# * [Image-to-Text](generative_ai/multimodal/Image_to_Text)
# * [Audio Generation](generative_ai/multimodal/Audio)
# * [Video Generation](generative_ai/multimodal/Video)
# * [3D Generation](generative_ai/multimodal/3D)
#
# :::
#
# :::{grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Training & Optimization</span>
# ^^^
#
# * [Training Data Preparation](generative_ai/training/Data_Preparation)
# * [Loss Functions](generative_ai/training/Loss_Functions)
# * [Optimization Algorithms](generative_ai/training/Optimization)
# * [Regularization Techniques](generative_ai/training/Regularization)
# * [Transfer Learning](generative_ai/training/Transfer_Learning)
# * [Distributed Training](generative_ai/training/Distributed_Training)
#
# :::
#
# :::{grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Advanced Techniques</span>
# ^^^
#
# * [Latent Space Manipulation](generative_ai/advanced/Latent_Spaces)
# * [Conditioning & Control](generative_ai/advanced/Conditioning)
# * [LoRA & Parameter-Efficient Fine-tuning](generative_ai/advanced/PEFT)
# * [Reinforcement Learning from Human Feedback (RLHF)](generative_ai/advanced/RLHF)
# * [Chain-of-Thought & Reasoning](generative_ai/advanced/Reasoning)
#
# :::
#
# :::{grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Evaluation & Metrics</span>
# ^^^
#
# * [Text Quality Metrics](generative_ai/evaluation/Text_Metrics)
# * [Image Quality Metrics](generative_ai/evaluation/Image_Metrics)
# * [Perceptual Metrics](generative_ai/evaluation/Perceptual_Metrics)
# * [Human Evaluation](generative_ai/evaluation/Human_Evaluation)
# * [Benchmark Datasets](generative_ai/evaluation/Benchmarks)
#
# :::
#
# :::{grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Ethics & Safety</span>
# ^^^
#
# * [Bias & Fairness](generative_ai/ethics/Bias_Fairness)
# * [Hallucinations & Factuality](generative_ai/ethics/Hallucinations)
# * [Deepfakes & Misinformation](generative_ai/ethics/Deepfakes)
# * [Copyright & IP Issues](generative_ai/ethics/IP)
# * [AI Safety & Alignment](generative_ai/ethics/Safety_Alignment)
# * [Responsible AI Guidelines](generative_ai/ethics/Responsible_AI)
#
# :::
#
# :::{grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Tools & Frameworks</span>
# ^^^
#
# * [PyTorch & TensorFlow](generative_ai/tools/Deep_Learning_Frameworks)
# * [Hugging Face Transformers](generative_ai/tools/Hugging_Face)
# * [OpenAI API](generative_ai/tools/OpenAI_API)
# * [LangChain & LlamaIndex](generative_ai/tools/LLM_Frameworks)
# * [Stable Diffusion WebUI](generative_ai/tools/SD_WebUI)
# * [MLOps & Deployment](generative_ai/tools/Deployment)
#
# :::
#
# :::{grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Applications</span>
# ^^^
#
# * [Chatbots & Conversational AI](generative_ai/applications/Chatbots)
# * [Content Creation](generative_ai/applications/Content_Creation)
# * [Code Generation](generative_ai/applications/Code_Generation)
# * [Drug Discovery](generative_ai/applications/Drug_Discovery)
# * [Creative Arts](generative_ai/applications/Creative_Arts)
# * [Personalization](generative_ai/applications/Personalization)
#
# :::
#
# :::{grid-item-card}
# :class-header: bg-grid-header
# :class-body: grid-center bg-grid-body
#
# <span class="grid-title">Research Frontiers</span>
# ^^^
#
# * [Scaling Laws](generative_ai/research/Scaling_Laws)
# * [Emergent Abilities](generative_ai/research/Emergent_Abilities)
# * [Model Compression](generative_ai/research/Compression)
# * [Few-Shot & Zero-Shot Learning](generative_ai/research/Few_Shot)
# * [Constitutional AI](generative_ai/research/Constitutional_AI)
# * [Future Directions](generative_ai/research/Future_Directions)
#
# :::
#
# ::::
