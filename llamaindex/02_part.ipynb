# %%
from data_loader import AsyncUniversalReader

# %%
reader = AsyncUniversalReader()

# %%
documents = await reader.aload_data("../datasets")

# %%
print(f"Loaded {len(documents)} documents.")
# Out:
# Loaded 10681574 documents.
